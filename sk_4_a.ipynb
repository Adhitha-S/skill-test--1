# %%
import pandas as pd
data = {
    'Participant': ['P1','P1','P2','P2','P3','P3'],
    'Electrode': ['E1','E2','E1','E2','E1','E2'],
    'Brainwave': [12.5, 15.2, 11.8, 14.6, 13.4, 16.1]
}

df = pd.DataFrame(data)
print("EEG Data")
print(df)

print("\nMean values:")
print(df.groupby('Participant')['Brainwave'].mean())

print("\nVariance:")
print(df.groupby('Participant')['Brainwave'].var())

print("\nPeak value:")
print(df['Brainwave'].max())
# Out:
# EEG Data
#   Participant Electrode  Brainwave
# 0          P1        E1       12.5
# 1          P1        E2       15.2
# 2          P2        E1       11.8
# 3          P2        E2       14.6
# 4          P3        E1       13.4
# 5          P3        E2       16.1
#
# Mean values:
# Participant
# P1    13.85
# P2    13.20
# P3    14.75
# Name: Brainwave, dtype: float64
#
# Variance:
# Participant
# P1    3.645
# P2    3.920
# P3    3.645
# Name: Brainwave, dtype: float64
#
# Peak value:
# 16.1
